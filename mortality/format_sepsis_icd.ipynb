# %% [markdown]
# ## Import Libraries

# %%
import os
import pandas as pd

import psycopg2

# %% [markdown]
# ## Connect to the DB

# %%
# information used to create a database connection
sqluser = 'postgres'
dbname = 'mimic4'
hostname = 'localhost'
port_number = 5434
schema_name = 'omop_cdm'

# Connect to postgres with a copy of the MIMIC-III database
con = psycopg2.connect(dbname=dbname, user=sqluser, host=hostname, port=port_number, password='mysecretpassword')

# the below statement is prepended to queries to ensure they select from the right schema
query_schema = 'set search_path to ' + schema_name + ';'

# %% [markdown]
# ## Read cohort

# %%
cohortQuery = """select * from sepsis_icd.cohort;"""
cohortDf = pd.read_sql_query(cohortQuery, con)
cohortDf
# Out:
#        visit_occurrence_id   person_id  sepsis
# 0              -2147462198  -421334407       1
# 1              -2147304039  1052438339       1
# 2              -2147110420  -322699580       1
# 3              -2147002424 -1242295740       1
# 4              -2146865542 -2139970486       1
# ...                    ...         ...     ...
# 38079            852091286  -565257984       0
# 38080           1522522265  1197088962       0
# 38081          -1199008181  1846272996       0
# 38082          -1413882544  1379728849       0
# 38083           -839457746 -2068381193       0
#
# [38084 rows x 3 columns]

# %% [markdown]
# ## Cohort counts

# %%
cohortCountsQuery = """
    with t1 as (
        select
        sepsis,
        count(distinct visit_occurrence_id) as visit_occurrence_count,
        count(distinct person_id) as person_count
        from
        sepsis_icd.cohort
        group by sepsis
    )
    select sepsis, visit_occurrence_count as cnt, 'visit_occurrence_count' as entity from t1
    union
    select sepsis, person_count as cnt, 'person_count' as entity from t1
    ;
"""
cohortCountsDf = pd.read_sql_query(cohortCountsQuery, con)
cohortCountsDf
# Out:
#    sepsis    cnt                  entity
# 0       0  19042  visit_occurrence_count
# 1       1  19042  visit_occurrence_count
# 2       0  13171            person_count
# 3       1  15668            person_count

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")
ax = sns.barplot(x='entity', y="cnt", hue='sepsis', data=cohortCountsDf)

# %% [markdown]
# ## Read static data

# %%
staticQuery = """select * from sepsis_icd.static;"""
staticDf = pd.read_sql_query(staticQuery, con)
staticDf
# Out:
#         person_id visit_start_datetime  visit_end_datetime  \
# 0       -45407753  2128-08-16 20:08:00 2128-09-01 12:25:00
# 1      -688080236  2119-04-27 07:15:00 2119-05-02 15:45:00
# 2       586098445  2143-02-19 07:15:00 2143-03-02 13:50:00
# 3     -2090043093  2157-07-22 07:15:00 2157-07-23 14:55:00
# 4     -1802428568  2119-07-26 07:15:00 2119-07-29 15:40:00
# ...           ...                  ...                 ...
# 38079   514388861  2188-07-14 15:56:00 2188-07-20 18:16:00
# 38080 -2046241961  2190-05-07 15:25:00 2190-05-19 15:29:00
# 38081 -1763850806  2188-06-14 12:24:00 2188-06-26 15:00:00
# 38082 -1833810949  2111-06-08 17:22:00 2111-06-22 02:25:00
# 38083   134031519  2143-01-28 20:42:00 2143-02-06 12:11:00
#
#        visit_occurrence_id visit_occurrence_concept_name  visit_duration_hrs  \
# 0               1661230940     Emergency Room - Hospital               376.0
# 1               -930244224    Ambulatory Surgical Center               128.0
# 2               -166442621    Ambulatory Surgical Center               270.0
# 3               -980240395    Ambulatory Surgical Center                31.0
# 4              -1963238015    Ambulatory Surgical Center                80.0
# ...                    ...                           ...                 ...
# 38079           1940413172     Emergency Room - Hospital               146.0
# 38080          -2009187990     Emergency Room - Hospital               288.0
# 38081           1360871926     Emergency Room - Hospital               290.0
# 38082           2130536448     Emergency Room - Hospital               321.0
# 38083            691302321     Emergency Room - Hospital               207.0
#
#          visit_source_concept_name admitting_source_value
# 0                     DIRECT EMER.     PHYSICIAN REFERRAL
# 1      SURGICAL SAME DAY ADMISSION     PHYSICIAN REFERRAL
# 2      SURGICAL SAME DAY ADMISSION     PHYSICIAN REFERRAL
# 3      SURGICAL SAME DAY ADMISSION     PHYSICIAN REFERRAL
# 4      SURGICAL SAME DAY ADMISSION     PHYSICIAN REFERRAL
# ...                            ...                    ...
# 38079                 DIRECT EMER.     PHYSICIAN REFERRAL
# 38080                 DIRECT EMER.        CLINIC REFERRAL
# 38081                 DIRECT EMER.        CLINIC REFERRAL
# 38082                 DIRECT EMER.     PHYSICIAN REFERRAL
# 38083                 DIRECT EMER.     PHYSICIAN REFERRAL
#
# [38084 rows x 8 columns]

# %% [markdown]
# ### Visit duration

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
plt.xticks(rotation = 45)
plt.hist(staticDf.visit_duration_hrs, bins=60)

ax.set_title('Visit Duration Histogram')
ax.set_xlabel('Visit Duration (Hours)')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Visit distribution

# %%
fig, ax = plt.subplots()
plt.xticks(rotation = 90)
staticDf.visit_occurrence_concept_name.value_counts().plot(kind='bar')

ax.set_title('Visit Distribution')
ax.set_ylabel('Count')
ax.set_xlabel('Visit')
# Out:
# Text(0.5, 0, 'Visit')

# %% [markdown]
# ### Visit source distribution

# %%
fig, ax = plt.subplots()
plt.xticks(rotation = 90)
staticDf.visit_source_concept_name.value_counts().plot(kind='bar')

ax.set_title('Visit Source Distribution')
ax.set_ylabel('Count')
ax.set_xlabel('Visit Source')
# Out:
# Text(0.5, 0, 'Visit Source')

# %% [markdown]
# ### Admitting source distribution

# %%
fig, ax = plt.subplots()
plt.xticks(rotation = 90)
staticDf.admitting_source_value.value_counts().plot(kind='bar')

ax.set_title('Admitting Source Distribution')
ax.set_ylabel('Count')
ax.set_xlabel('Admitting Source')
# Out:
# Text(0.5, 0, 'Admitting Source')
